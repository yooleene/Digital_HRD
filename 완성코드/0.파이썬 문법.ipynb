# %% [markdown]
# # A.파이썬 기본지식

# %% [markdown]
# #### 파이썬 관련된 지식 site https://wikidocs.net/5

# %% [markdown]
# # B.기본연산

# %% [markdown]
# ### B-1.출력하기

# %%
print(1)
print("Hello, World!")

# %% [markdown]
# ### B-2.비교하기

# %%
1 < 2

# %%
1 > 2

# %%
1 == 2

# %%
1 >= 2

# %% [markdown]
# ### B-3.계산하기

# %%
print(5+3)
print(5*3)
print(5/3)
print(5%3)
print(5//3)

# %% [markdown]
# ### B-4.주석처리

# %%
print(5+3)
# print(5*3)
print(5/3)
# print(5%3)
print(5//3)
# 주석처리하고 싶은 코드에 만 앞에 # 놔두기

# %% [markdown]
# ### B-5.들여쓰기

# %%
# 들여쓰기 없음
if 3 < 7:
print("3 is less than 7")

# %%
# 들여쓰기 있음
if 3 < 7:
    print("3 is less than 7")

# %% [markdown]
# ### B-6.입력

# %%
#변수란?
a = 1

# %%
print(a)

# %%
# 인풋이란 무엇인가?
input()

# %%
# 문자열 출력
print("당신의 이름은 무엇입니까? :")
# 입력 값을 my_name 변수에 저장
my_name = input()
# 문자열과 변수 값을 출력
print(my_name + "!!!")

# %% [markdown]
# # C.변수와 자료형

# %% [markdown]
# ### C-1.변수의 사용

# %% [markdown]
# ##### 예제 C-1-1

# %%
language = "python"
print(language)
# Out:
# 파이썬

# %% [markdown]
# ##### 예제 C-1-2

# %%
#대문자 소문자 구분 필수

Name = "Tom"
nAme = "Paul"
NAME = "Ben"

print(Name)
print(nAme)
print(NAME)

# %% [markdown]
# ### C-2.기본 자료형
# - 숫자형 (Number) : int, float, complex (숫자)
# - 문자열 (String) : str (문자)
# - 불린형 (Boolean) : bool ( 참/거짓)

# %% [markdown]
# 자료형 관련 함수
#
# - 자료형 확인 함수
#     - type()

# %% [markdown]
# ##### 예제 C-2-1

# %%
a = 'tom'
type(a)

# %%
b = 1
type(b)

# %% [markdown]
# 문자열
#
# - 문자가 나열된 형태의 데이터
#
#
# - 가장 많이 사용되는 자료형 중 하나
#
#
# - 큰 따옴표 ( " " ) 또는 작은 따옴표 ( ' ' ) 를 사용

# %% [markdown]
# ##### 예제 C-2-2

# %%
print('This is also a name.')
print('This is also a "name".')
print("This is also a 'name'.")

# %% [markdown]
# ### C-3 인덱싱 (Indexing) 과 슬라이싱 (Slicing)

# %% [markdown]
# #### C-3-1.인덱싱

# %%
language = "python"
print(language[1])
print(language[0])
print(language[3])
print(language[-3])
print(language[-5])

# %% [markdown]
# #### C-3-2. 슬라이싱 (Slicing)

# %%
language = "python"

print(language[3:])
print(language[:2])
print(language[:-2])
# Out:
# hon
# py
# pyth

# %% [markdown]
# # D.	데이터구조

# %% [markdown]
# ### D-1.데이터구조란?
#
# 엑셀을 예로 들어보면, 행/열로 우리가 원하는 데이터를 저장하고 우리가 원할때 그 데이터를 가져올 수 있는 데이터구조
#
# 우리가 알고 있는 표와 같다.
#
# 그런데, 코딩에서는 단순 2차원인 표뿐만 아니라 3차,4차 N차원까지 자료를 저장할 수 있다.
#
# 그래서 데이터 구조를 이해하면 새로운 환경으로 진입할 수 있다.

# %% [markdown]
# #### D-1-1.데이터 구조의 종류
# #### 리스트 / 튜플 / 딕셔너리 / 세트 / Range  등이 있다.

# %% [markdown]
# ### D-2. 리스트의 개념
#
# - 왜 필요한가?
#     - 100명의 사원 이름을 저장하려면 100개의 변수가 필요
#         - employee1 = 'bhyunco'
#         - employee2 = 'bhyunsoon'
#         - ...
#     - 하나의 변수에 할당할 수 없을까?
#         - employee = ['bhyunco', 'bhyunsoon', ...]
#
#
# - 여러 데이터가 순서대로 들어있는 시퀀스 자료형
#     - 요소 (element) : 리스트에 들어 있는 각각의 값
#     - 시퀀스 자료형의 종류 : List, Tuple, Range
#
#
# - \[ \] (대괄호) 기호를 이용하여 생성

# %% [markdown]
# ##### 예제 D-2-1

# %%
word1 = "is"
word2 = "nice"
my_list = ["my", "list", word1, word2, 'list']
print(my_list)

# %% [markdown]
# ##### 예제 D-2-2
#
# 인덱싱 + 슬라이싱

# %%
my_list = ['my', 'list', 'is', 'nice', 'list']

#인덱싱
print(my_list[0])
print(my_list[1])
print(my_list[2])
print(my_list[-1])
print("\n")

#슬라이싱1
print(my_list[0:3])
print(my_list[:4])
print(my_list[2:])
# Out:
# my
# list
# is
# list
#
#
# ['my', 'list', 'is']
# ['my', 'list', 'is', 'nice']
# ['is', 'nice', 'list']

# %% [markdown]
# ##### 예제 D-2-3
# 요소 추가
#
# - 차례로 추가
#     - append() 함수

# %%
motorcycles = ['kia', 'yamaha']
print(motorcycles)

motorcycles.append('suzuki')
print(motorcycles)

# %% [markdown]
# ##### 예제 D-2-4
# - 길이 계산

# %%
cars = ['bmw', 'audi', 'toyota', 'hyundai']
print(len(cars))

# %% [markdown]
# ### D-3. 딕셔너리의 개념
# - Key-Value 형태의 자료구조
#
#
# - 왜 딕셔너리를 사용하는가?
#     - 학생정보 리스트
#         - ['A001', '홍길동', '85', 'B']
#         - 리스트는 각 데이터의 의미를 알기 어려움
#     - 딕셔너리는 각 데이터에 이름을 붙여줌
#         - 학번: 'A001', 이름: '홍길동', 점수: '85', 성적: 'B'
#
#
# - { } 기호를 사용하여 생성
#
#
# `{ Key1: Value1,
#    Key2: Value2,
#    ... }`
#
#
# - Key 값으로 Value를 조회

# %% [markdown]
# ##### 예제 D-3-1

# %%
property = {
    'color': 'green',
    'points': 5,
}
print(alien['color'])
print(alien['points'])

# %% [markdown]
# ##### 예제 D-3-2 (요소추가)

# %%
property['x_position'] = 0
property['y_position'] = 25

print(property)

# %% [markdown]
# ### D-4. Range 의 개념
# - 시퀀스 자료형
#
#
# - 시작, 끝, 증가폭 지정
#
#
# - 시작 포함, 끝 제외
#
#
# - 시작과 증가폭은 생략 가능
#
#
# - 음수 증가폭 가능

# %% [markdown]
# ##### 예제 D-4-1

# %%
my_range = range(5)
print(my_range)
print(list(my_range))

# %% [markdown]
# ##### 예제 D-4-2

# %%
my_range = range(2, 5)
print(list(my_range))

# %% [markdown]
# ##### 예제 D-4-3

# %%
my_range = range(1, 7, 2)
print(list(my_range))

# %% [markdown]
# # E.	If 문 (조건문)
#
# - 조건에 따라 다른 동작을 수행하여 프로그램을 분기
#
#
# - 조건문이 필요한 프로그램의 예
#     - 아이디와 비밀번호 정보가 틀리면 로그인 실패 메시지를 출력

# %% [markdown]
# ##### 예제 E-1

# %%
a = 33
b = 33

if a > b:
    print("a is greater than b")
elif a < b:
    print("a is less than b")
else:
    print("a is not greater than b and not less than b")

# %% [markdown]
# # F.	For 문 (반복문)

# %% [markdown]
# ##### 예제 E-2

# %%
numbers = [0,1,2,3,4]

for a in numbers:
    print(a)

# %% [markdown]
# ##### 예제 E-3

# %%
for a in range(10):
    print(a)

# %% [markdown]
# ##### 예제 E-4

# %%
fruits = ['lemon', 'kiwi', 'orange']

for a in fruits:
    print("I like " + a + ".")
print("I ate " + a + " today.\n")

# %% [markdown]
# ##### 예제 E-5

# %%
number = 1
while number < 10:
    print(number)
    number += 1
