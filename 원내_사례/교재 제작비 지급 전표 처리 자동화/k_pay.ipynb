# %% [markdown]
# ##### 1.KSystem 로그인 정보 입력

# %%
import pyautogui as pg
import clipboard as cb
import sys
import pandas as pd

#패스워드 입력
my_pw = pg.password(title='KSystem_PASS', text='패스워드를 입력하세요', default='')

# %% [markdown]
# ##### 2.전표에 들어갈 내용(엑셀) 복사하기

# %%
# 전표에 들어갈 내용(엑셀) 판다스로 불러오기

pg.sleep(1)
win = pg.getWindowsWithTitle('sample') #교육생명단 엑셀화면 활성화
if win[0].isActive == False:
    win[0].activate()

pg.sleep(2)
pg.hotkey('ctrl','home') #A1셀로 이동
pg.sleep(0.5)
pg.hotkey('ctrl','a') #전체 셀 선택
pg.sleep(0.5)
pg.hotkey('ctrl','c') #클립보드로 복사
pg.sleep(1)
df = pd.read_clipboard() #판다스로 클립보드의 데이터를 읽기
df

# %% [markdown]
# #### 3. 변수명 지정

# %%
account1 = df.iloc[0,1] # 1행_계정과목
account2 = df.iloc[1,1] # 2행_계정과목
account3 = df.iloc[2,1] # 3행_계정과목
account1_cha = df.iloc[0,3] # 차변금액
account3_cha = df.iloc[2,4] # 대변금액
account_com = df.iloc[0,5] # 적요
account_buseo = df.iloc[0,6]  # 귀속부서
account_actcen = df.iloc[0,8] # 활동센터
account1_jun = df.iloc[0,9] # 1행_계정과목의 증빙
account2_jun = df.iloc[1,9] # 2행_계정과목의 증빙
account3_chul = df.iloc[2,10] # 3행_출납예정일
account_gu = df.iloc[0,11] # 거래처
account1_gan1 = df.iloc[0,12] # 1행_관리항목
account2_gan1 = df.iloc[1,12] # 2행_공급가액
account2_gan2 = df.iloc[1,13] # 2행_거래일
account2_gan3 = df.iloc[1,14] # 2행_사업자번호
account2_gan4 = df.iloc[1,15] # 2행-불공제구분
account2_gan5 = df.iloc[1,16] # 2행-불공제세
account3_gan1 = df.iloc[2,12] # 3행_금융기관
account3_gan2 = df.iloc[2,13] # 3행_지급계좌

# %% [markdown]
# ##### 4.KSystem 로그인

# %%
#ksystem 실행
pg.hotkey('win', 'r')
pg.write(r"C:\Users\Public\Appdata\local\Younglimwon\KSystem ver.5 Genuine\Updater\ClientUpdater.exe")
pg.press('enter')
pg.sleep(5)
pg.write(my_pw)
pg.press('enter')

#Quick Search로 이동
pg.sleep(3)
pg.hotkey('ctrl','f11') #Quick Search 단축키
cb.copy('분개전표입력') #메뉴 검색 키워드 복사
pg.hotkey('ctrl','v') #메뉴 검색 키워드 붙여넣기
pg.press('enter') #검색하기
pg.press('tab', presses=3)
pg.press('down', presses=2)
pg.sleep(3)
             
#분개전표입력 클릭
btn_journal = pg.locateCenterOnScreen('btn_journal.png', confidence=0.9) #이미지는 메뉴에서 잘못 찾기도 해서 0.9로 변경
if btn_journal != None: pg.doubleClick(btn_journal) #분개전표입력 클릭
else:
      print('분개전표입력을 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()
pg.hotkey('win','up') #창 최대화 

#계정과목 클릭
pg.sleep(5)
btn_account = pg.locateCenterOnScreen('btn_account.png', confidence=0.8)
btn_account_act = pg.locateCenterOnScreen('btn_account_act.png', confidence=0.8)
if btn_account != None or btn_account_act != None: 
      pg.doubleClick(btn_account)
      pg.doubleClick(btn_account_act)
else:
      print('계정과목을 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()

# %% [markdown]
# ##### 5.데이터 입력

# %%
#KSystem 화면 활성화
pg.sleep(1)
win = pg.getWindowsWithTitle('(주)포스코인재창조원')
if win[0].isActive == False:
    win[0].activate()

# %%
#입력 시작---------------------------------------------------------
pg.sleep(3)
pg.doubleClick(btn_account.x, btn_account.y+25) #첫 입력만 계정과목 클릭 후 입력 시작하고 다음부터는 행 추가 후 바로 입력
pg.sleep(3)
cb.copy(account1)  # 한글은 클립보드에 넣어서 붙여넣기 함
pg.hotkey('ctrl','v')
pg.press('enter', presses=2, interval=0.2)
pg.sleep(1)

pg.press('enter', presses=2, interval=0.2)
pg.sleep(0.5)

#차변금액
pg.sleep(0.5)
cb.copy(account1_cha) 
pg.hotkey('ctrl','v')
pg.sleep(0.5)
pg.press('enter', presses=2)   
                                  
#적요
pg.sleep(0.5)
cb.copy(account_com)
pg.hotkey('ctrl','v')
pg.press('enter')

#귀속부서

pg.sleep(0.5)
cb.copy(account_buseo)
pg.hotkey('ctrl','v')
pg.press('enter')

#활동센터
pg.sleep(0.5)
cb.copy(account_actcen)
pg.hotkey('ctrl','v')
pg.press('enter')

# %%
#차변 하단 내용----------------------------

#하단을 입력하기 위해 해당 그룹으로 이동
pg.sleep(2)
pg.click(btn_account.x+800, btn_account.y-50) #상단 그룹의 빈 공백 클릭(다음에 탭으로 이동)

#증빙
pg.sleep(0.5)
pg.press('tab', presses=6, interval=0.2)
cb.copy(account1_jun)
pg.hotkey('ctrl','v')
pg.press('enter')

#거래처
pg.sleep(2)
btn_customer = pg.locateCenterOnScreen('btn_customer.png', confidence=0.8)
if btn_customer != None: 
      pg.doubleClick(btn_customer.x, btn_customer.y+25)
else:
      print('거래처를 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()
      
#거래처명을 선택하기 위해 목록으로 이동
pg.sleep(2)
btn_customer_search = pg.locateCenterOnScreen('btn_customer_search.png', confidence=0.8)
if btn_customer_search != None: 
      pg.click(btn_customer_search)
      # pg.click(btn_customer_search.x-700, btn_customer_search.y)
      
      pg.press('enter')
else:
      print('거래처 코드를 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()
pg.sleep(0.5)
pg.press('tab')
pg.sleep(1)
cb.copy(account_gu)
pg.hotkey('ctrl', 'v')
pg.press('enter', presses=3, interval=0.2)
#제조비용_잡비
pg.sleep(0.5)
cb.copy(account1_gan1)
pg.hotkey('ctrl','v')

# %%
#행추가
pg.sleep(2)
btn_row = pg.locateCenterOnScreen('btn_row.png', confidence=0.8)
if btn_row != None: 
      pg.click(btn_row)
else:
      print('행추가를 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()

# %%
# 2번째 항 입력
pg.sleep(2)
cb.copy(account2)  # 한글은 클립보드에 넣어서 붙여넣기 함
pg.hotkey('ctrl','v')
pg.press('enter', presses=2, interval=0.2)
pg.sleep(1)

# 일반매입부가세
pg.sleep(0.5)
pg.write("0")
pg.sleep(0.5)
pg.press('enter', presses=2)   
                                  
#적요
pg.sleep(1)
cb.copy(account_com)
pg.hotkey('ctrl','v')
pg.press('enter')

#귀속부서

pg.sleep(0.5)
cb.copy(account_buseo)
pg.hotkey('ctrl','v')
pg.press('enter')

#활동센터
pg.sleep(0.5)
cb.copy(account_actcen)
pg.hotkey('ctrl','v')
pg.press('enter')

# %%
#차변 하단 내용----------------------------

#하단을 입력하기 위해 해당 그룹으로 이동
pg.sleep(2)
pg.click(btn_account.x+800, btn_account.y-50) #상단 그룹의 빈 공백 클릭(다음에 탭으로 이동)

#증빙
pg.sleep(0.5)
pg.press('tab', presses=5, interval=0.2)
cb.copy(account2_jun)
pg.hotkey('ctrl','v')
pg.press('enter')

#거래처
pg.sleep(2)
btn_customer = pg.locateCenterOnScreen('btn_customer.png', confidence=0.8)
if btn_customer != None: 
      pg.doubleClick(btn_customer.x, btn_customer.y+25)
else:
      print('거래처를 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()
      
#거래처명을 선택하기 위해 목록으로 이동
pg.sleep(2)
btn_customer_search = pg.locateCenterOnScreen('btn_customer_search.png', confidence=0.8)
if btn_customer_search != None: 
      pg.click(btn_customer_search)
      # pg.click(btn_customer_search.x-700, btn_customer_search.y)
      
      pg.press('enter')
else:
      print('거래처 코드를 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()
pg.sleep(0.5)
pg.press('tab')
pg.sleep(1)
cb.copy(account_gu)
pg.hotkey('ctrl', 'v')
pg.press('enter', presses=3, interval=0.2)
#공급가액 입력
pg.write(account2_gan1)
pg.sleep(1)
pg.press('enter')

#거래일 입력
pg.write(account2_gan2)
pg.sleep(1)
pg.press('enter')

#불공제구분
pg.press('enter', presses = 1)
pg.sleep(1)
cb.copy(account2_gan4)
pg.hotkey('ctrl','v')
pg.press('enter')

#불공제세 입력
pg.sleep(1)
cb.copy(account2_gan5)
pg.hotkey('ctrl', 'v')
pg.press('enter')

# %%
#행추가
pg.sleep(2)
btn_row = pg.locateCenterOnScreen('btn_row.png', confidence=0.8)
if btn_row != None: 
      pg.click(btn_row)
else:
      print('행추가를 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()

# %%
# 3번째 항 입력
pg.sleep(2)
cb.copy(account3)  # 한글은 클립보드에 넣어서 붙여넣기 함
pg.hotkey('ctrl','v')
pg.press('enter', presses=3, interval=0.2)
pg.sleep(1)

pg.hotkey('tab', presses = 2)
                                
#적요
pg.sleep(0.5)
cb.copy(account_com)
pg.hotkey('ctrl','v')
pg.press('enter')

#귀속부서
pg.sleep(1)
cb.copy(account_buseo)
pg.hotkey('ctrl','v')
pg.press('enter')

#활동센터
pg.sleep(0.5)
cb.copy(account_actcen)
pg.hotkey('ctrl','v')
pg.press('enter')

# %%
#하단을 입력하기 위해 해당 그룹으로 이동
pg.sleep(2)
pg.click(btn_account.x+800, btn_account.y-50) #상단 그룹의 빈 공백 클릭(다음에 탭으로 이동)

#출납예정일
pg.sleep(0.5)
pg.press('tab', presses=8, interval=0.2)
cb.copy(account3_chul)
pg.hotkey('ctrl','v')
pg.press('enter')

#거래처
pg.sleep(2)
btn_customer = pg.locateCenterOnScreen('btn_customer.png', confidence=0.8)
if btn_customer != None: 
      pg.doubleClick(btn_customer.x, btn_customer.y+25)
else:
      print('거래처를 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()
      
#거래처명을 선택하기 위해 목록으로 이동
pg.sleep(2)
btn_customer_search = pg.locateCenterOnScreen('btn_customer_search.png', confidence=0.8)
if btn_customer_search != None: 
      pg.click(btn_customer_search)
      # pg.click(btn_customer_search.x-700, btn_customer_search.y)
      
      pg.press('enter')
else:
      print('거래처 코드를 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()
pg.sleep(0.5)
pg.press('tab')
pg.sleep(1)
cb.copy(account_gu)
pg.hotkey('ctrl', 'v')
pg.press('enter', presses=3, interval=0.2)

#금융기관 입력
pg.sleep(1)
cb.copy(account3_gan1)
pg.hotkey('ctrl', 'v')
pg.sleep(1)
pg.press('enter')
pg.sleep(1)

#지급계좌 입력
pg.write(account3_gan2)
pg.sleep(1)
pg.press('enter')

# %%
#저장하기
pg.sleep(1)
btn_save = pg.locateCenterOnScreen('btn_save.png', confidence=0.8)
if btn_save != None: 
      pg.click(btn_save)
else:
      print('저장 버튼을 클릭하지 못했습니다. RPA 작업을 재시도 하세요.')
      sys.exit()
